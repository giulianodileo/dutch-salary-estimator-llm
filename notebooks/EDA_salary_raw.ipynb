# %% [markdown]
# # Initiation & JSON conversin

# %%
import json
import pandas as pd
import os
import re

# %% [markdown]
# data_dict[1]['position']

# %%
# Function to extract numbers from seniority
def extract_numbers(s):
    # Find all numbers in the string
    numbers = re.findall(r'\d+', s)
    # Convert to integers
    return [int(n) for n in numbers]

# %%
# CLEAING EXTRACTING SENIORITY & UPDATING

string = data_dict[1]['seniority']
res = extract_numbers(string)
val1 = int(res[0])
val2 = int(res[1])
val = (val1 + val2) / 2
seniority = []

for i in data_dict.keys():
    string = data_dict[i]['seniority']
    res = extract_numbers(string)
    val1 = int(res[0])
    val2 = int(res[1])
    val = (val1 + val2) / 2

    if val <= 2:
        res = "junior"
    elif val > 2 and val <= 5:
        res = "mid-level"
    else:
        res = "senior"

    data_dict[i]['seniority'] = res

# %%
# FUNCTION TO EXTRACT SALARIES#
###############################

def extract_salary(s):
    # Find all numbers in the string (including K)
    matches = re.findall(r'(\d+)[Kk]?', s)
    # Convert to floats and multiply by 1000 if 'K' is present
    numbers = [float(n) * 1000 for n in matches]
    if numbers:
        return {'min_amount': min(numbers), 'max_amount': max(numbers)}
    else:
        return {'min_amount': None, 'max_amount': None}

# Apply extraction to dictionary
for key, value in data_dict.items():
    salary_range = extract_salary(value['salary'])
    value.update(salary_range)

# %%
# EXTRACTING SALARIS IN DICTIONARY - MEDIAN LEVEL
salary = {}

for i in data_dict.keys():
    string = data_dict[i]['salary']
    res = extract_salary(string)
    salary[i] = res

for i in data_dict.keys():
    data_dict[i]['avg_amount'] = (data_dict[i]['min_amount'] + data_dict[i]['max_amount']) / 2

# %%
def normalize_role(role: str) -> str:
    """
    Normalize job titles to match JSON golden standard values.
    If exact match exists, return unchanged.
    If alias exists, map to JSON value.
    If no match, return None.
    """

    # Golden standard roles from JSON
    golden_roles = {
        "Data Scientist": "Data Scientist",
        "Data Analyst": "Data Analyst",
        "Data Engineer": "Data Engineer",
        "Software Engineer": "Software Engineer",
        "DevOps Engineer": "DevOps Engineer",
        "Security Engineer": "Security Engineer",
        "Front End Developer / Engineer": "Front End Developer / Engineer",
        "Back End Developer/ Engineer": "Back End Developer/ Engineer"
    }

    # Alias mapping → maps your input roles to golden JSON values
    alias_map = {
        "Frontend Engineer": "Front End Developer / Engineer",
        "Backend Engineer": "Back End Developer/ Engineer",
        "Devops Engineer": "DevOps Engineer",
        "Ai Engineer": "Ai Engineer",       # not in JSON
        "Cloud Engineer": "Cloud Engineer"   # not in JSON
    }

    # Exact match first
    if role in golden_roles:
        return role

    # Check alias map
    if role in alias_map:
        return alias_map[role]

    # If not found, return or role if you prefer)
    return role

# %%
for i in data_dict.keys():
    role = data_dict[i]['position']
    data_dict[i]['position'] = normalize_role(role)


check_role = []

for i in data_dict.keys():
    check_role.append(data_dict[i]['position'])

# %%
# Save to JSON file
with open("data_dict.json", "w", encoding="utf-8") as f:
    json.dump(data, f, indent=4, ensure_ascii=False)

# %%
data_dict
# Out:
# {0: {'position': 'Data Scientist',
#   'seniority': 'junior',
#   'salary': '€\xa050K\xa0-\xa0€\xa070K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-scientist-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 50000.0,
#   'max_amount': 70000.0,
#   'avg_amount': 60000.0},
#  1: {'position': 'Data Scientist',
#   'seniority': 'mid-level',
#   'salary': '€\xa061K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-scientist-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 61000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 70500.0},
#  2: {'position': 'Data Scientist',
#   'seniority': 'senior',
#   'salary': '€\xa065K\xa0-\xa0€\xa086K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-scientist-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 65000.0,
#   'max_amount': 86000.0,
#   'avg_amount': 75500.0},
#  3: {'position': 'Data Analyst',
#   'seniority': 'junior',
#   'salary': '€\xa045K\xa0-\xa0€\xa062K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-analyst-salarissen-SRCH_IL.0,9_IN178_KO10,22.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 45000.0,
#   'max_amount': 62000.0,
#   'avg_amount': 53500.0},
#  4: {'position': 'Data Analyst',
#   'seniority': 'mid-level',
#   'salary': '€\xa057K\xa0-\xa0€\xa074K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-analyst-salarissen-SRCH_IL.0,9_IN178_KO10,22.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 57000.0,
#   'max_amount': 74000.0,
#   'avg_amount': 65500.0},
#  5: {'position': 'Data Analyst',
#   'seniority': 'senior',
#   'salary': '€\xa057K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-analyst-salarissen-SRCH_IL.0,9_IN178_KO10,22.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 57000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 68500.0},
#  6: {'position': 'Data Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa047K\xa0-\xa0€\xa065K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,23.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 47000.0,
#   'max_amount': 65000.0,
#   'avg_amount': 56000.0},
#  7: {'position': 'Data Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa056K\xa0-\xa0€\xa076K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,23.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 56000.0,
#   'max_amount': 76000.0,
#   'avg_amount': 66000.0},
#  8: {'position': 'Data Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa060K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-data-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,23.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 60000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 70000.0},
#  9: {'position': 'Software Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa050K\xa0-\xa0€\xa075K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-software-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 50000.0,
#   'max_amount': 75000.0,
#   'avg_amount': 62500.0},
#  10: {'position': 'Software Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa060K\xa0-\xa0€\xa085K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-software-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 60000.0,
#   'max_amount': 85000.0,
#   'avg_amount': 72500.0},
#  11: {'position': 'Software Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa065K\xa0-\xa0€\xa090K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-software-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 65000.0,
#   'max_amount': 90000.0,
#   'avg_amount': 77500.0},
#  12: {'position': None,
#   'seniority': 'junior',
#   'salary': '€\xa03K\xa0-\xa0€\xa04K/mnd',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-cloud-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 3000.0,
#   'max_amount': 4000.0,
#   'avg_amount': 3500.0},
#  13: {'position': None,
#   'seniority': 'mid-level',
#   'salary': '€\xa04K\xa0-\xa0€\xa05K/mnd',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-cloud-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 4000.0,
#   'max_amount': 5000.0,
#   'avg_amount': 4500.0},
#  14: {'position': None,
#   'seniority': 'senior',
#   'salary': '€\xa062K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-cloud-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,24.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 62000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 71000.0},
#  15: {'position': None,
#   'seniority': 'junior',
#   'salary': '€\xa03K\xa0-\xa0€\xa04K/mnd',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-ai-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,21.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 3000.0,
#   'max_amount': 4000.0,
#   'avg_amount': 3500.0},
#  16: {'position': None,
#   'seniority': 'mid-level',
#   'salary': '€\xa070K\xa0-\xa0€\xa090K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-ai-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,21.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 70000.0,
#   'max_amount': 90000.0,
#   'avg_amount': 80000.0},
#  17: {'position': None,
#   'seniority': 'senior',
#   'salary': '€\xa057K–€\xa092K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-ai-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,21.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 57000.0,
#   'max_amount': 92000.0,
#   'avg_amount': 74500.0},
#  18: {'position': 'Front End Developer / Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa047K\xa0-\xa0€\xa075K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-frontend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 47000.0,
#   'max_amount': 75000.0,
#   'avg_amount': 61000.0},
#  19: {'position': 'Front End Developer / Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa058K\xa0-\xa0€\xa075K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-frontend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 58000.0,
#   'max_amount': 75000.0,
#   'avg_amount': 66500.0},
#  20: {'position': 'Front End Developer / Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa060K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-frontend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 60000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 70000.0},
#  21: {'position': 'Back End Developer/ Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa048K\xa0-\xa0€\xa070K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-backend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,26.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 48000.0,
#   'max_amount': 70000.0,
#   'avg_amount': 59000.0},
#  22: {'position': 'Back End Developer/ Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa058K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-backend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,26.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 58000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 69000.0},
#  23: {'position': 'Back End Developer/ Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa060K\xa0-\xa0€\xa081K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-backend-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,26.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 60000.0,
#   'max_amount': 81000.0,
#   'avg_amount': 70500.0},
#  24: {'position': 'DevOps Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa049K\xa0-\xa0€\xa064K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-devops-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,25.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 49000.0,
#   'max_amount': 64000.0,
#   'avg_amount': 56500.0},
#  25: {'position': 'DevOps Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa056K\xa0-\xa0€\xa070K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-devops-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,25.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 56000.0,
#   'max_amount': 70000.0,
#   'avg_amount': 63000.0},
#  26: {'position': 'DevOps Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa060K\xa0-\xa0€\xa075K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-devops-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,25.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 60000.0,
#   'max_amount': 75000.0,
#   'avg_amount': 67500.0},
#  27: {'position': 'Security Engineer',
#   'seniority': 'junior',
#   'salary': '€\xa048K\xa0-\xa0€\xa074K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-security-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 48000.0,
#   'max_amount': 74000.0,
#   'avg_amount': 61000.0},
#  28: {'position': 'Security Engineer',
#   'seniority': 'mid-level',
#   'salary': '€\xa056K\xa0-\xa0€\xa080K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-security-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 56000.0,
#   'max_amount': 80000.0,
#   'avg_amount': 68000.0},
#  29: {'position': 'Security Engineer',
#   'seniority': 'senior',
#   'salary': '€\xa068K\xa0-\xa0€\xa095K/jr',
#   'source_url': 'https://www.glassdoor.nl/Salarissen/nederland-security-engineer-salarissen-SRCH_IL.0,9_IN178_KO10,27.htm',
#   'source_site': 'glassdoor',
#   'min_amount': 68000.0,
#   'max_amount': 95000.0,
#   'avg_amount': 81500.0}}
